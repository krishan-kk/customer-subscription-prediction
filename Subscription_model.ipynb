# %%
import numpy as np
import tensorflow as tf

# %%
npz = np.load('subscriptions_data_train.npz')
train_inputs = npz['inputs'].astype(float)
train_targets = npz['targets'].astype(int)

# %%
npz = np.load('subscriptions_data_validation.npz')
validation_inputs, validation_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %%
npz = np.load('subscriptions_data_test.npz')
test_inputs, test_targets = npz['inputs'].astype(float), npz['targets'].astype(int)

# %%
#model
input_size = 10
output_size = 2
hidden_layer_size = 50
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 1st hidden layer
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'), # 2nd hidden layer
    tf.keras.layers.Dense(output_size, activation='softmax') # output layer
])

# %%
#loss function
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
#training
batch_size = 100
max_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience=5, restore_best_weights=True)
model.fit(train_inputs,
          train_targets, 
          batch_size=batch_size,
          epochs=max_epochs, 
          callbacks=[early_stopping],
          validation_data=(validation_inputs, validation_targets),
          verbose = 2
          )
# Out:
# Epoch 1/100
# 36/36 - 2s - 62ms/step - accuracy: 0.6108 - loss: 0.6340 - val_accuracy: 0.7472 - val_loss: 0.5189
# Epoch 2/100
# 36/36 - 0s - 8ms/step - accuracy: 0.7552 - loss: 0.4776 - val_accuracy: 0.7852 - val_loss: 0.4297
# Epoch 3/100
# 36/36 - 0s - 8ms/step - accuracy: 0.7857 - loss: 0.4167 - val_accuracy: 0.8098 - val_loss: 0.3886
# Epoch 4/100
# 36/36 - 0s - 8ms/step - accuracy: 0.7924 - loss: 0.3889 - val_accuracy: 0.8188 - val_loss: 0.3665
# Epoch 5/100
# 36/36 - 0s - 8ms/step - accuracy: 0.7963 - loss: 0.3746 - val_accuracy: 0.8188 - val_loss: 0.3557
# Epoch 6/100
# 36/36 - 0s - 7ms/step - accuracy: 0.8013 - loss: 0.3637 - val_accuracy: 0.8233 - val_loss: 0.3452
# Epoch 7/100
# 36/36 - 0s - 7ms/step - accuracy: 0.8058 - loss: 0.3622 - val_accuracy: 0.8076 - val_loss: 0.3434
# Epoch 8/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8036 - loss: 0.3561 - val_accuracy: 0.8188 - val_loss: 0.3448
# Epoch 9/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8122 - loss: 0.3503 - val_accuracy: 0.8210 - val_loss: 0.3404
# Epoch 10/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8103 - loss: 0.3455 - val_accuracy: 0.8166 - val_loss: 0.3338
# Epoch 11/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8145 - loss: 0.3428 - val_accuracy: 0.8322 - val_loss: 0.3372
# Epoch 12/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8136 - loss: 0.3406 - val_accuracy: 0.8255 - val_loss: 0.3306
# Epoch 13/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8114 - loss: 0.3392 - val_accuracy: 0.8255 - val_loss: 0.3301
# Epoch 14/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8100 - loss: 0.3384 - val_accuracy: 0.8300 - val_loss: 0.3237
# Epoch 15/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8192 - loss: 0.3335 - val_accuracy: 0.8277 - val_loss: 0.3229
# Epoch 16/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8142 - loss: 0.3332 - val_accuracy: 0.8345 - val_loss: 0.3251
# Epoch 17/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8220 - loss: 0.3343 - val_accuracy: 0.8322 - val_loss: 0.3229
# Epoch 18/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8175 - loss: 0.3314 - val_accuracy: 0.8367 - val_loss: 0.3204
# Epoch 19/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8153 - loss: 0.3294 - val_accuracy: 0.8412 - val_loss: 0.3189
# Epoch 20/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8187 - loss: 0.3280 - val_accuracy: 0.8300 - val_loss: 0.3215
# Epoch 21/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8153 - loss: 0.3294 - val_accuracy: 0.8166 - val_loss: 0.3311
# Epoch 22/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8184 - loss: 0.3264 - val_accuracy: 0.8367 - val_loss: 0.3191
# Epoch 23/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8178 - loss: 0.3258 - val_accuracy: 0.8345 - val_loss: 0.3188
# Epoch 24/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8256 - loss: 0.3235 - val_accuracy: 0.8434 - val_loss: 0.3170
# Epoch 25/100
# 36/36 - 0s - 11ms/step - accuracy: 0.8203 - loss: 0.3248 - val_accuracy: 0.8255 - val_loss: 0.3213
# Epoch 26/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8251 - loss: 0.3238 - val_accuracy: 0.8188 - val_loss: 0.3256
# Epoch 27/100
# 36/36 - 0s - 8ms/step - accuracy: 0.8187 - loss: 0.3202 - val_accuracy: 0.8255 - val_loss: 0.3230
# Epoch 28/100
# 36/36 - 0s - 9ms/step - accuracy: 0.8178 - loss: 0.3244 - val_accuracy: 0.8188 - val_loss: 0.3319
# Epoch 29/100
# 36/36 - 0s - 10ms/step - accuracy: 0.8279 - loss: 0.3233 - val_accuracy: 0.8322 - val_loss: 0.3202

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8326 - loss: 0.3259
